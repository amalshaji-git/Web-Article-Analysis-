# %% [markdown]
# Load and Display Excel Data

# %%
import pandas as pd
data1= pd.read_excel(r"C:\Users\amals\Desktop\project\Input.xlsx")
pd.set_option('display.max_columns', None)
data1
# Out:
#               URL_ID                                                URL
# 0    Netclan20241017  https://insights.blackcoffer.com/ai-and-ml-bas...
# 1    Netclan20241018  https://insights.blackcoffer.com/enhancing-fro...
# 2    Netclan20241019  https://insights.blackcoffer.com/roas-dashboar...
# 3    Netclan20241020  https://insights.blackcoffer.com/efficient-pro...
# 4    Netclan20241021  https://insights.blackcoffer.com/development-o...
# ..               ...                                                ...
# 142  Netclan20241159  https://insights.blackcoffer.com/population-an...
# 143  Netclan20241160  https://insights.blackcoffer.com/google-lsa-ap...
# 144  Netclan20241161  https://insights.blackcoffer.com/healthcare-da...
# 145  Netclan20241162  https://insights.blackcoffer.com/budget-sales-...
# 146  Netclan20241163  https://insights.blackcoffer.com/amazon-buy-bo...
#
# [147 rows x 2 columns]

# %% [markdown]
# This script loads data from an Excel file named Input.xlsx using the pandas library. It sets the display option to show all columns, ensuring that no columns are hidden when viewing the DataFrame. The loaded data is then displayed in its entirety for easy inspection and analysis.

# %% [markdown]
# Load and Display Output Data Structure

# %%
import pandas as pd
data2= pd.read_excel(r"C:\Users\amals\Desktop\project\Output Data Structure.xlsx")
pd.set_option('display.max_columns', None)
data2
# Out:
#      URL_ID                                                URL  \
# 0         1  https://insights.blackcoffer.com/is-telehealth...
# 1         2  https://insights.blackcoffer.com/how-telehealt...
# 2         3  https://insights.blackcoffer.com/is-telemedici...
# 3         4  https://insights.blackcoffer.com/is-telehealth...
# 4         5  https://insights.blackcoffer.com/how-people-di...
# ..      ...                                                ...
# 145     146  https://insights.blackcoffer.com/blockchain-fo...
# 146     147  https://insights.blackcoffer.com/the-future-of...
# 147     148  https://insights.blackcoffer.com/big-data-anal...
# 148     149  https://insights.blackcoffer.com/business-anal...
# 149     150  https://insights.blackcoffer.com/challenges-an...
#
#      POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0                43               8        0.680000            0.049000
# 1                47              16        0.490000            0.030000
# 2                89              28        0.520000            0.033000
# 3                68              24        0.470000            0.024000
# 4                88              34        0.440000            0.029000
# ..              ...             ...             ...                 ...
# 145              29              28        0.017544            0.001073
# 146              47              14        0.540984            0.020561
# 147              32              48       -0.200000           -0.013479
# 148              39               4        0.813953            0.047490
# 149              47              41        0.068182            0.005687
#
#      AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0             173.420000                     0.350000  69.510000
# 1             105.120000                     0.270000  42.160000
# 2             124.060000                     0.350000  49.770000
# 3             135.540000                     0.370000  54.360000
# 4             148.120000                     0.320000  59.380000
# ..                   ...                          ...        ...
# 145           111.730769                     0.282189  44.805183
# 146           159.316667                     0.282243  63.839564
# 147           103.485294                     0.307498  41.517117
# 148           161.033333                     0.351425  64.553903
# 149            95.545455                     0.264455  38.323964
#
#      AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                           26.690000                 249         703
# 1                           17.610000                 272         995
# 2                           18.750000                 634        1795
# 3                           20.250000                 677        1811
# 4                           22.650000                 613        1859
# ..                                ...                 ...         ...
# 145                         17.615385                 263         932
# 146                         25.933333                 453        1605
# 147                         17.073529                 365        1187
# 148                         24.066667                 259         737
# 149                         15.969697                 279        1055
#
#      SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                 1470                  0         5.460000
# 1                 1857                  0         4.890000
# 2                 3925                  1         5.560000
# 3                 3966                  0         5.650000
# 4                 3940                  1         5.510000
# ..                 ...                ...              ...
# 145               1811                 11         5.306867
# 146               3047                 18         5.023676
# 147               2300                  3         5.007582
# 148               1566                  0         5.616011
# 149               2065                  8         5.040758
#
# [150 rows x 15 columns]

# %% [markdown]
# This script loads data from an Excel file named Output Data Structure.xlsx using the pandas library. It sets the display option to show all columns, ensuring that no columns are hidden when viewing the DataFrame. The loaded data is then displayed in its entirety for review, allowing for easy verification of the expected output structure for the project.

# %% [markdown]
# Web Article Extractor

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os

input_path = r"C:\Users\amals\Desktop\project\Input.xlsx"
data = pd.read_excel(input_path)

# Function to extract article title and body using BeautifulSoup
def extract_article(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Extract the title
            title = soup.find('title').get_text()
            
            # Extract the article body (assuming it's under <p> tags)
            article_text = ' '.join([p.get_text() for p in soup.find_all('p')])
            
            return title, article_text
        else:
            return None, None
    except Exception as e:
        print(f"Error extracting {url}: {e}")
        return None, None

# Create a folder to save the extracted articles
output_folder = r"C:\Users\amals\Desktop\project\extracted_articles"  # Adjust this path
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Loop through each row in the pandas DataFrame and extract the article
for index, row in data.iterrows():
    url_id = row['URL_ID']  # Get URL_ID from the Excel file
    url = row['URL']        # Get URL from the Excel file
    
    # Extract article using BeautifulSoup
    title, article_text = extract_article(url)
    
    # If extraction is successful, save the data
    if title and article_text:
        content = f"Title: {title}\n\n{article_text}"  # Combine title and article text
        
        # Save the content to a text file named with the URL_ID
        file_path = os.path.join(output_folder, f"{url_id}.txt")
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(content)
        
        print(f"Article {url_id} saved to {file_path}")
    else:
        print(f"Failed to extract article {url_id} from {url}")
# Out:
# Article Netclan20241017 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241017.txt
# Article Netclan20241018 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241018.txt
# Article Netclan20241019 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241019.txt
# Article Netclan20241020 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241020.txt
# Article Netclan20241021 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241021.txt
# Article Netclan20241022 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241022.txt
# Article Netclan20241023 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241023.txt
# Article Netclan20241024 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241024.txt
# Article Netclan20241025 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241025.txt
# Article Netclan20241026 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241026.txt
# Article Netclan20241027 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241027.txt
# Article Netclan20241028 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241028.txt
# Article Netclan20241029 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241029.txt
# Article Netclan20241030 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241030.txt
# Article Netclan20241031 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241031.txt
# Article Netclan20241032 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241032.txt
# Article Netclan20241033 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241033.txt
# Article Netclan20241034 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241034.txt
# Article Netclan20241035 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241035.txt
# Article Netclan20241036 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241036.txt
# Article Netclan20241037 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241037.txt
# Article Netclan20241038 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241038.txt
# Article Netclan20241039 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241039.txt
# Article Netclan20241040 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241040.txt
# Article Netclan20241041 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241041.txt
# Article Netclan20241042 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241042.txt
# Article Netclan20241043 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241043.txt
# Article Netclan20241044 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241044.txt
# Article Netclan20241045 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241045.txt
# Article Netclan20241046 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241046.txt
# Article Netclan20241047 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241047.txt
# Article Netclan20241048 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241048.txt
# Article Netclan20241049 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241049.txt
# Article Netclan20241050 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241050.txt
# Article Netclan20241051 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241051.txt
# Article Netclan20241052 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241052.txt
# Article Netclan20241053 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241053.txt
# Article Netclan20241054 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241054.txt
# Article Netclan20241055 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241055.txt
# Article Netclan20241056 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241056.txt
# Article Netclan20241057 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241057.txt
# Article Netclan20241058 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241058.txt
# Article Netclan20241059 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241059.txt
# Article Netclan20241060 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241060.txt
# Article Netclan20241061 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241061.txt
# Article Netclan20241062 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241062.txt
# Article Netclan20241063 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241063.txt
# Article Netclan20241064 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241064.txt
# Article Netclan20241065 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241065.txt
# Article Netclan20241066 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241066.txt
# Article Netclan20241067 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241067.txt
# Article Netclan20241068 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241068.txt
# Article Netclan20241069 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241069.txt
# Article Netclan20241070 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241070.txt
# Article Netclan20241071 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241071.txt
# Article Netclan20241072 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241072.txt
# Article Netclan20241073 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241073.txt
# Article Netclan20241074 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241074.txt
# Article Netclan20241075 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241075.txt
# Article Netclan20241076 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241076.txt
# Article Netclan20241077 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241077.txt
# Article Netclan20241078 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241078.txt
# Article Netclan20241079 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241079.txt
# Article Netclan20241080 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241080.txt
# Article Netclan20241081 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241081.txt
# Article Netclan20241082 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241082.txt
# Article Netclan20241083 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241083.txt
# Article Netclan20241084 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241084.txt
# Article Netclan20241085 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241085.txt
# Article Netclan20241086 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241086.txt
# Article Netclan20241087 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241087.txt
# Article Netclan20241088 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241088.txt
# Article Netclan20241089 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241089.txt
# Article Netclan20241090 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241090.txt
# Article Netclan20241091 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241091.txt
# Article Netclan20241092 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241092.txt
# Article Netclan20241093 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241093.txt
# Article Netclan20241094 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241094.txt
# Article Netclan20241095 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241095.txt
# Article Netclan20241096 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241096.txt
# Article Netclan20241097 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241097.txt
# Article Netclan20241098 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241098.txt
# Article Netclan20241099 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241099.txt
# Article Netclan20241100 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241100.txt
# Article Netclan20241101 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241101.txt
# Article Netclan20241102 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241102.txt
# Article Netclan20241103 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241103.txt
# Article Netclan20241104 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241104.txt
# Article Netclan20241105 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241105.txt
# Article Netclan20241106 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241106.txt
# Article Netclan20241107 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241107.txt
# Article Netclan20241108 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241108.txt
# Article Netclan20241109 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241109.txt
# Article Netclan20241110 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241110.txt
# Article Netclan20241111 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241111.txt
# Article Netclan20241112 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241112.txt
# Article Netclan20241113 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241113.txt
# Article Netclan20241114 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241114.txt
# Article Netclan20241115 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241115.txt
# Article Netclan20241116 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241116.txt
# Article Netclan20241117 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241117.txt
# Article Netclan20241118 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241118.txt
# Article Netclan20241119 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241119.txt
# Article Netclan20241120 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241120.txt
# Article Netclan20241121 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241121.txt
# Article Netclan20241122 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241122.txt
# Article Netclan20241123 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241123.txt
# Article Netclan20241124 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241124.txt
# Article Netclan20241125 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241125.txt
# Article Netclan20241126 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241126.txt
# Article Netclan20241127 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241127.txt
# Article Netclan20241128 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241128.txt
# Article Netclan20241129 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241129.txt
# Article Netclan20241130 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241130.txt
# Article Netclan20241131 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241131.txt
# Article Netclan20241132 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241132.txt
# Article Netclan20241133 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241133.txt
# Article Netclan20241134 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241134.txt
# Article Netclan20241135 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241135.txt
# Article Netclan20241136 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241136.txt
# Article Netclan20241137 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241137.txt
# Article Netclan20241138 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241138.txt
# Article Netclan20241139 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241139.txt
# Article Netclan20241140 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241140.txt
# Article Netclan20241141 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241141.txt
# Article Netclan20241142 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241142.txt
# Article Netclan20241143 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241143.txt
# Article Netclan20241144 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241144.txt
# Article Netclan20241145 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241145.txt
# Article Netclan20241146 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241146.txt
# Article Netclan20241147 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241147.txt
# Article Netclan20241148 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241148.txt
# Article Netclan20241149 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241149.txt
# Article Netclan20241150 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241150.txt
# Article Netclan20241151 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241151.txt
# Article Netclan20241152 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241152.txt
# Article Netclan20241153 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241153.txt
# Article Netclan20241154 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241154.txt
# Article Netclan20241155 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241155.txt
# Article Netclan20241156 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241156.txt
# Article Netclan20241157 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241157.txt
# Article Netclan20241158 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241158.txt
# Article Netclan20241159 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241159.txt
# Article Netclan20241160 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241160.txt
# Article Netclan20241161 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241161.txt
# Article Netclan20241162 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241162.txt
# Article Netclan20241163 saved to C:\Users\amals\Desktop\project\extracted_articles\Netclan20241163.txt

# %% [markdown]
# This script extracts article titles and bodies from a list of URLs provided in an Excel file (Input.xlsx). It uses the requests library to fetch webpage content and BeautifulSoup to parse the HTML. The extracted titles and article texts are saved as text files in a designated output folder named after the article's URL_ID. This process ensures that each article is stored in a structured format, ready for further analysis or processing.

# %% [markdown]
# Article Text Analysis and Output Generation

# %%
import os
import pandas as pd
from textblob import TextBlob
import re
import nltk
from nltk.corpus import cmudict

# Path to extracted articles folder
extracted_articles_path = r"C:\Users\amals\Desktop\project\extracted_articles"

# Load the output structure Excel file (for structure/order reference)
output_structure_path = r"C:\Users\amals\Desktop\project\Output Data Structure.xlsx"
output_data_structure = pd.read_excel(output_structure_path)

# Dictionary to store syllables for complex word calculation
d = cmudict.dict()

# Helper function to count syllables in a word
def syllable_count(word):
    word = word.lower()
    if word in d:
        return max([len([y for y in x if y[-1].isdigit()]) for x in d[word]])
    else:
        return 1  # Default to 1 syllable if not found

# Check if a word is complex (3 or more syllables)
def is_complex(word):
    return syllable_count(word) >= 3

# Function to perform analysis for each article
def analyze_article(text):
    # TextBlob for sentiment analysis
    blob = TextBlob(text)
    
    # 1. Positive Score: Use your own logic or predefined sentiment lexicons
    positive_score = sum(1 for word in blob.words if TextBlob(word).sentiment.polarity > 0)
    
    # 2. Negative Score: Similar logic as positive score
    negative_score = sum(1 for word in blob.words if TextBlob(word).sentiment.polarity < 0)
    
    # 3. Polarity Score
    polarity_score = blob.sentiment.polarity
    
    # 4. Subjectivity Score
    subjectivity_score = blob.sentiment.subjectivity
    
    # 5. Average Sentence Length
    sentences = blob.sentences
    avg_sentence_length = sum(len(sentence.words) for sentence in sentences) / len(sentences)
    
    # 6. Percentage of Complex Words
    words = blob.words
    complex_words_count = sum(1 for word in words if is_complex(word))
    percentage_of_complex_words = (complex_words_count / len(words)) * 100
    
    # 7. Average Number of Words per Sentence
    avg_words_per_sentence = len(words) / len(sentences)
    
    # 8. Complex Word Count
    complex_word_count = complex_words_count
    
    # 9. Word Count
    word_count = len(words)
    
    # 10. Syllables per Word
    total_syllables = sum(syllable_count(word) for word in words)
    syllables_per_word = total_syllables / len(words)
    
    # 11. Personal Pronouns (using regex to find occurrences of personal pronouns)
    personal_pronouns = len(re.findall(r'\b(I|we|my|ours|us)\b', text, re.I))
    
    # 12. Average Word Length
    avg_word_length = sum(len(word) for word in words) / len(words)
    
    # Return results in the specified order
    return [positive_score, negative_score, polarity_score, subjectivity_score, avg_sentence_length, 
            percentage_of_complex_words, avg_words_per_sentence, complex_word_count, word_count, 
            syllables_per_word, personal_pronouns, avg_word_length]

# Create a list to store the results for all articles
results = []

# Loop through each article file
for file_name in os.listdir(extracted_articles_path):
    if file_name.endswith(".txt"):
        url_id = file_name.split('.')[0]  # Get URL_ID from the file name
        with open(os.path.join(extracted_articles_path, file_name), 'r', encoding='utf-8') as file:
            text = file.read()
            # Perform analysis on the article text
            analysis_result = analyze_article(text)
            # Append the URL_ID and analysis results to the list
            results.append([url_id] + analysis_result)

# Convert the results to a pandas DataFrame
columns = ['URL_ID', 'Positive Score', 'Negative Score', 'Polarity Score', 'Subjectivity Score', 
           'Avg Sentence Length', 'Percentage of Complex Words', 'Avg Number of Words per Sentence', 
           'Complex Word Count', 'Word Count', 'Syllables per Word', 'Personal Pronouns', 'Avg Word Length']

output_df = pd.DataFrame(results, columns=columns)

# Save the DataFrame to a new Excel file in the same order as "Output Data Structure.xlsx"
output_df.to_excel(r"C:\Users\amals\Desktop\project\final_output.xlsx", index=False)

print("Text analysis completed and saved in final_output.xlsx")
# Out:
# Text analysis completed and saved in final_output.xlsx

# %% [markdown]
# This script analyzes text from extracted articles stored in a specified folder. It performs various analyses, including sentiment scoring, average sentence length, complex word percentage, and more. The results are compiled into a structured DataFrame and saved as an Excel file named final_output.xlsx. The output follows the specified order defined in the "Output Data Structure.xlsx" file, ensuring compatibility for further analysis or reporting.

# %% [markdown]
# Project Documentation for Text Analysis

# %%
import pandas as pd

# Load the CSV file
data = pd.read_excel(r"C:\Users\amals\Desktop\project\Output Data Structure.xlsx")

data['AVG_POSITIVE_SCORE'] = data['POSITIVE SCORE'].mean()
data['AVG_NEGATIVE_SCORE'] = data['NEGATIVE SCORE'].mean()
# Save the updated DataFrame to a new CSV file
data.to_csv(' analysis_results.csv', index=False)

# %% [markdown]
# Code to Extract and Combine Articles from URLs

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os

# Load the data
input_file_path = r"C:\Users\amals\Desktop\project\Input.xlsx"
df = pd.read_excel(input_file_path)

# Specify the directory and file path
combined_folder_path = r'C:\Users\amals\Desktop\project\combined_file'
combined_file_path = os.path.join(combined_folder_path, 'combined_articles.txt')

# Create the combined folder if it doesn't exist
os.makedirs(combined_folder_path, exist_ok=True)

# Function to extract text from a URL
def extract_text(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Check for HTTP errors
        soup = BeautifulSoup(response.content, 'html.parser')
        return soup.get_text()
    except requests.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None

# Open the combined file for writing
with open(combined_file_path, 'w', encoding='utf-8') as combined_file:
    # Iterate through the DataFrame and extract text from each URL
    for index, row in df.iterrows():
        url = row['URL']
        article_text = extract_text(url)
        
        if article_text:
            # Write the URL_ID and the article text into the combined file
            combined_file.write(f"URL_ID: {row['URL_ID']}\n")
            combined_file.write(article_text)
            combined_file.write("\n\n")  # Separate articles with a blank line
            
            print(f"Article from {url} saved to combined file.")
        else:
            print(f"Failed to extract article from {url}")

print(f"All articles combined into: {combined_file_path}")
# Out:
# Article from https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/ saved to combined file.
# Article from https://insights.blackcoffer.com/enhancing-front-end-features-and-functionality-for-improved-user-experience-and-dashboard-accuracy-in-partner-hospital-application/ saved to combined file.
# Article from https://insights.blackcoffer.com/roas-dashboard-for-campaign-wise-google-ads-budget-tracking-using-google-ads-ap/ saved to combined file.
# Article from https://insights.blackcoffer.com/efficient-processing-and-analysis-of-financial-data-from-pdf-files-addressing-formatting-inconsistencies-and-ensuring-data-integrity-for-a-toyota-dealership-management-firm/ saved to combined file.
# Article from https://insights.blackcoffer.com/development-of-ea-robot-for-automated-trading/ saved to combined file.
# Article from https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/ saved to combined file.
# Article from https://insights.blackcoffer.com/enhancing-front-end-features-and-functionality-for-improved-user-experience-and-dashboard-accuracy-in-partner-hospital-application/ saved to combined file.
# Article from https://insights.blackcoffer.com/roas-dashboard-for-campaign-wise-google-ads-budget-tracking-using-google-ads-ap/ saved to combined file.
# Article from https://insights.blackcoffer.com/efficient-processing-and-analysis-of-financial-data-from-pdf-files-addressing-formatting-inconsistencies-and-ensuring-data-integrity-for-a-toyota-dealership-management-firm/ saved to combined file.
# Article from https://insights.blackcoffer.com/transforming-and-managing-a-large-scale-sql-pedigree-database-to-neo4j-graph-db/ saved to combined file.
# Article from https://insights.blackcoffer.com/enhancing-model-accuracy-from-58-to-over-90-strategies-for-improving-predictive-performance/ saved to combined file.
# Article from https://insights.blackcoffer.com/securing-sensitive-financial-data-with-privacy-preserving-machine-learning-for-predictive-analytics/ saved to combined file.
# Article from https://insights.blackcoffer.com/enhancing-data-collection-for-research-institutions-addressing-survey-fatigue-and-incorporating-verbal-communication-for-richer-insights/ saved to combined file.
# Article from https://insights.blackcoffer.com/analyzing-the-impact-of-positive-emotions-and-pandemic-severity-on-mental-health-and-resilience-among-entrepreneurs-insights-and-predictive-modeling/ saved to combined file.
# Article from https://insights.blackcoffer.com/dynamic-brand-centric-dashboard-for-automotive-dealerships-pdf-to-financial-insights-with-flask-react-architecture-and-aws-cloud-hosting/ saved to combined file.
# Article from https://insights.blackcoffer.com/cloud-based-data-modeling-and-analysis-platform-with-drag-and-drop-interface-and-openai-api-integration-for-simulation-insights/ saved to combined file.
# Article from https://insights.blackcoffer.com/voter-profile-analysis-and-search-application-for-targeted-campaign-engagement-using-government-voter-data/ saved to combined file.
# Article from https://insights.blackcoffer.com/bert-based-classification-of-individuals-and-organizations-into-two-categories-using-natural-language-processing/ saved to combined file.
# Article from https://insights.blackcoffer.com/comprehensive-analysis-of-solana-and-ethereum-contributors-using-github-api-with-comparative-study-of-1000-random-github-profiles/ saved to combined file.
# Article from https://insights.blackcoffer.com/powerbi-rest-api-fetching-dataflow-and-refresh-schedules-with-semantic-models/ saved to combined file.
# Article from https://insights.blackcoffer.com/automated-job-data-import-and-management-solution-for-enhanced-efficiency/ saved to combined file.
# Article from https://insights.blackcoffer.com/data-analytics-and-optimization-solution-for-enhancing-renewable-energy-efficiency/ saved to combined file.
# Article from https://insights.blackcoffer.com/time-series-analysis-and-trend-forecasting-solution-for-predicting-news-trends/ saved to combined file.
# Article from https://insights.blackcoffer.com/advanced-data-visualization-solutions-for-monitoring-key-business-metrics-with-integrated-interactive-dashboards/ saved to combined file.
# Article from https://insights.blackcoffer.com/advanced-patient-data-analysis-solution-for-trend-identification-and-improved-healthcare-outcome/ saved to combined file.
# Article from https://insights.blackcoffer.com/anomaly-detection-and-analysis-for-enhanced-data-integrity-and-user-experience-on-bright-datas-website/ saved to combined file.
# Article from https://insights.blackcoffer.com/building-custom-tflite-models-and-benchmarking-on-voxl2-chips/ saved to combined file.
# Article from https://insights.blackcoffer.com/sports-prediction-model-for-multiple-sports-leagues/ saved to combined file.
# Article from https://insights.blackcoffer.com/efficient-coach-allocation-system-for-sports-coaching-organization/ saved to combined file.
# Article from https://insights.blackcoffer.com/data-studio-dashboard-with-a-data-pipeline-tool-synced-with-podio-using-custom-webhooks-and-google-cloud-function-2/ saved to combined file.
# Article from https://insights.blackcoffer.com/ai-driven-backend-for-audio-to-text-conversion-and-analytical-assessment-in-pharmaceutical-practice/ saved to combined file.
# Article from https://insights.blackcoffer.com/cloud-based-web-application-for-financial-data-processing-and-visualization-of-sp-500-metrics/ saved to combined file.
# Article from https://insights.blackcoffer.com/department-wise-kpi-tracking-dashboard-with-technician-performance-analysis-for-atoz-dependable-service/ saved to combined file.
# Article from https://insights.blackcoffer.com/steps-to-convert-a-node-js-api-to-python-for-aws-lambda-deployment/ saved to combined file.
# Article from https://insights.blackcoffer.com/building-an-analytics-dashboard-with-a-pdf-parsing-pipeline-for-data-extraction/ saved to combined file.
# Article from https://insights.blackcoffer.com/building-a-real-time-log-file-visualization-dashboard-in-kibana/ saved to combined file.
# Article from https://insights.blackcoffer.com/analyzing-the-impact-of-female-ceo-appointments-on-company-stock-prices/ saved to combined file.
# Article from https://insights.blackcoffer.com/ai-chatbot-using-llm-langchain-llama/ saved to combined file.
# Article from https://insights.blackcoffer.com/healthcare-ai-chatbot-using-llama-llm-langchain/ saved to combined file.
# Article from https://insights.blackcoffer.com/ai-bot-audio-to-audio/ saved to combined file.
# Article from https://insights.blackcoffer.com/recommendation-engine-for-insurance-sector-to-expand-business-in-the-rural-area/ saved to combined file.
# Article from https://insights.blackcoffer.com/data-from-crm-via-zapier-to-google-sheets-dynamic-to-powerbi/ saved to combined file.
# Article from https://insights.blackcoffer.com/data-warehouse-to-google-data-studio-looker-dashboard/ saved to combined file.
# Article from https://insights.blackcoffer.com/crm-monday-com-via-zapier-to-power-bi-dashboard/ saved to combined file.
# Article from https://insights.blackcoffer.com/monday-com-to-kpi-dashboard-to-manage-view-and-generate-insights-from-the-crm-data/ saved to combined file.
# Article from https://insights.blackcoffer.com/data-management-for-a-political-saas-application/ saved to combined file.
# Article from https://insights.blackcoffer.com/google-lsa-ads-google-local-service-ads-etl-tools-and-dashboards/ saved to combined file.
# Article from https://insights.blackcoffer.com/ad-networks-marketing-campaign-data-dashboard-in-looker-google-data-studio/ saved to combined file.
# Article from https://insights.blackcoffer.com/analytical-solution-for-a-tech-firm/ saved to combined file.
# Article from https://insights.blackcoffer.com/ai-solution-for-a-technology-information-and-internet-firm/ saved to combined file.
# Article from https://insights.blackcoffer.com/ai-and-nlp-based-solutions-to-automate-data-discovery-for-venture-capital-and-private-equity-principals/ saved to combined file.
# Article from https://insights.blackcoffer.com/an-etl-solution-for-an-internet-publishing-firm/ saved to combined file.
# Article from https://insights.blackcoffer.com/ai-based-algorithmic-trading-bot-for-forex/ saved to combined file.
# Article from https://insights.blackcoffer.com/equity-waterfalls-model-based-saas-application-for-real-estate-sector/ saved to combined file.
# Article from https://insights.blackcoffer.com/ai-solutions-for-foreign-exchange-an-automated-algo-trading-tool/ saved to combined file.
# Article from https://insights.blackcoffer.com/ai-agent-development-and-deployment-in-jina-ai/ saved to combined file.
# Article from https://insights.blackcoffer.com/golden-record-a-knowledge-graph-database-approach-to-unfold-discovery-using-neo4j/ saved to combined file.
# Article from https://insights.blackcoffer.com/advanced-ai-for-trading-automation/ saved to combined file.
# Article from https://insights.blackcoffer.com/create-a-knowledge-graph-to-provide-real-time-analytics-recommendations-and-a-single-source-of-truth/ saved to combined file.
# Article from https://insights.blackcoffer.com/advanced-ai-for-thermal-person-detection/ saved to combined file.
# Article from https://insights.blackcoffer.com/advanced-ai-for-road-cam-threat-detection/ saved to combined file.
# Article from https://insights.blackcoffer.com/advanced-ai-for-pedestrian-crossing-safety/ saved to combined file.
# Article from https://insights.blackcoffer.com/handgun-detection-using-yolo/ saved to combined file.
# Article from https://insights.blackcoffer.com/using-graph-technology-to-create-single-customer-view/ saved to combined file.
# Article from https://insights.blackcoffer.com/car-detection-in-satellite-images/ saved to combined file.
# Article from https://insights.blackcoffer.com/building-a-physics-informed-neural-network-for-circuit-evaluation/ saved to combined file.
# Article from https://insights.blackcoffer.com/connecting-mongodb-database-to-power-bi-dashboard-dashboard-automation/ saved to combined file.
# Article from https://insights.blackcoffer.com/data-transformation/ saved to combined file.
# Article from https://insights.blackcoffer.com/e-commerce-store-analysis-purchase-behavior-ad-spend-conversion-traffic-etc/ saved to combined file.
# Article from https://insights.blackcoffer.com/kpi-dashboard-for-accountants/ saved to combined file.
# Article from https://insights.blackcoffer.com/return-on-advertising-spend-dashboard-marketing-automation-and-analytics-using-etl-and-dashboard/ saved to combined file.
# Article from https://insights.blackcoffer.com/ranking-customer-behaviours-for-business-strategy/ saved to combined file.
# Article from https://insights.blackcoffer.com/algorithmic-trading-for-multiple-commodities-markets-like-forex-metals-energy-etc/ saved to combined file.
# Article from https://insights.blackcoffer.com/trading-bot-for-forex/ saved to combined file.
# Article from https://insights.blackcoffer.com/python-model-for-the-analysis-of-sector-specific-stock-etfs-for-investment-purposes%ef%bf%bc/ saved to combined file.
# Article from https://insights.blackcoffer.com/medical-classification/ saved to combined file.
# Article from https://insights.blackcoffer.com/design-develop-bert-question-answering-model-explanations-with-visualization/ saved to combined file.
# Article from https://insights.blackcoffer.com/design-and-develop-solution-to-anomaly-detection-classification-problems/ saved to combined file.
# Article from https://insights.blackcoffer.com/an-etl-solution-for-currency-data-to-google-big-query/ saved to combined file.
# Article from https://insights.blackcoffer.com/etl-and-mlops-infrastructure-for-blockchain-analytics/ saved to combined file.
# Article from https://insights.blackcoffer.com/an-agent-based-model-of-a-virtual-power-plant-vpp/ saved to combined file.
# Article from https://insights.blackcoffer.com/transform-api-into-sdk-library-and-widget/ saved to combined file.
# Article from https://insights.blackcoffer.com/integration-of-a-product-to-a-cloud-based-crm-platform/ saved to combined file.
# Article from https://insights.blackcoffer.com/a-web-based-dashboard-for-the-filtered-data-retrieval-of-land-records/ saved to combined file.
# Article from https://insights.blackcoffer.com/integration-of-video-conferencing-data-to-the-existing-web-app/ saved to combined file.
# Article from https://insights.blackcoffer.com/design-develop-an-app-in-retool-which-shows-the-progress-of-the-added-video/ saved to combined file.
# Article from https://insights.blackcoffer.com/auvik-connectwise-integration-in-grafana/ saved to combined file.
# Article from https://insights.blackcoffer.com/data-integration-and-big-data-performance-using-elk-stack/ saved to combined file.
# Article from https://insights.blackcoffer.com/web-data-connector/ saved to combined file.
# Article from https://insights.blackcoffer.com/an-app-for-updating-the-email-id-of-the-user-and-stripe-refund-tool-using-retool/ saved to combined file.
# Article from https://insights.blackcoffer.com/an-ai-ml-based-web-application-that-detects-the-correctness-of-text-in-a-given-video/ saved to combined file.
# Article from https://insights.blackcoffer.com/website-tracking-and-insights-using-google-analytics-google-tag-manager/ saved to combined file.
# Article from https://insights.blackcoffer.com/dashboard-to-track-the-analytics-of-the-website-using-google-analytics-and-google-tag-manager/ saved to combined file.
# Article from https://insights.blackcoffer.com/power-bi-dashboard-on-operations-transactions-and-marketing-embedding-the-dashboard-to-web-app/ saved to combined file.
# Article from https://insights.blackcoffer.com/nft-data-automation-looksrare-and-etl-tool/ saved to combined file.
# Article from https://insights.blackcoffer.com/optimize-the-data-scraper-program-to-easily-accommodate-large-files-and-solve-oom-errors/ saved to combined file.
# Article from https://insights.blackcoffer.com/making-a-robust-way-to-sync-data-from-airtables-to-mongodb-using-python-etl-solution/ saved to combined file.
# Article from https://insights.blackcoffer.com/incident-duration-prediction-infrastructure-and-real-estate/ saved to combined file.
# Article from https://insights.blackcoffer.com/statistical-data-analysis-of-reinforced-concrete/ saved to combined file.
# Article from https://insights.blackcoffer.com/database-normalization-segmentation-with-google-data-studio-dashboard-insights/ saved to combined file.
# Article from https://insights.blackcoffer.com/power-bi-dashboard-to-drive-insights-from-complex-data-to-generate-business-insights/ saved to combined file.
# Article from https://insights.blackcoffer.com/real-time-dashboard-to-monitor-infrastructure-activity-and-machines/ saved to combined file.
# Article from https://insights.blackcoffer.com/electric-vehicles-ev-load-management-system-to-forecast-energy-demand/ saved to combined file.
# Article from https://insights.blackcoffer.com/power-bi-data-driven-map-dashboard/ saved to combined file.
# Article from https://insights.blackcoffer.com/google-local-service-ads-lsa-leads-dashboard/ saved to combined file.
# Article from https://insights.blackcoffer.com/aws-lex-voice-and-chatbot/ saved to combined file.
# Article from https://insights.blackcoffer.com/metabridges-api-decentraland-integration/ saved to combined file.
# Article from https://insights.blackcoffer.com/microsoft-azure-chatbot-with-luis-language-understanding/ saved to combined file.
# Article from https://insights.blackcoffer.com/impact-of-news-media-and-press-on-innovation-startups-and-investments/ saved to combined file.
# Article from https://insights.blackcoffer.com/aws-quicksight-reporting-dashboard/ saved to combined file.
# Article from https://insights.blackcoffer.com/google-data-studio-dashboard-for-marketing-ads-and-traction-data/ saved to combined file.
# Article from https://insights.blackcoffer.com/gangala-in-e-commerce-big-data-etl-elt-solution-and-data-warehouse/ saved to combined file.
# Article from https://insights.blackcoffer.com/big-data-solution-to-an-online-multivendor-marketplace-ecommerce-business/ saved to combined file.
# Article from https://insights.blackcoffer.com/creating-a-custom-report-and-dashboard-using-the-data-got-from-atera-api/ saved to combined file.
# Article from https://insights.blackcoffer.com/azure-data-lake-and-power-bi-dashboard/ saved to combined file.
# Article from https://insights.blackcoffer.com/google-data-studio-pipeline-with-gcp-mysql/ saved to combined file.
# Article from https://insights.blackcoffer.com/quickbooks-dashboard-to-find-patterns-in-finance-sales-and-forecasts/ saved to combined file.
# Article from https://insights.blackcoffer.com/marketing-sales-and-financial-data-business-dashboard-wink-report/ saved to combined file.
# Article from https://insights.blackcoffer.com/react-native-apps-in-the-development-portfolio/ saved to combined file.
# Article from https://insights.blackcoffer.com/a-leading-firm-website-seo-optimization/ saved to combined file.
# Article from https://insights.blackcoffer.com/a-leading-hospitality-firm-in-the-usa-website-seo-optimization/ saved to combined file.
# Article from https://insights.blackcoffer.com/a-leading-firm-in-the-usa-website-seo-optimization/ saved to combined file.
# Article from https://insights.blackcoffer.com/a-leading-musical-instrumental-website-seo-optimization/ saved to combined file.
# Article from https://insights.blackcoffer.com/a-leading-firm-in-the-usa-seo-and-website-optimization/ saved to combined file.
# Article from https://insights.blackcoffer.com/immigration-datawarehouse-ai-based-recommendations/ saved to combined file.
# Article from https://insights.blackcoffer.com/lipsync-automation-for-celebrities-and-influencers/ saved to combined file.
# Article from https://insights.blackcoffer.com/key-audit-matters-predictive-modeling/ saved to combined file.
# Article from https://insights.blackcoffer.com/splitting-of-songs-into-its-vocals-and-instrumental/ saved to combined file.
# Article from https://insights.blackcoffer.com/ai-and-ml-technologies-to-evaluate-learning-assessments/ saved to combined file.
# Article from https://insights.blackcoffer.com/datawarehouse-and-recommendations-engine-for-airbnb/ saved to combined file.
# Article from https://insights.blackcoffer.com/real-estate-data-warehouse/ saved to combined file.
# Article from https://insights.blackcoffer.com/traction-dashboards-of-marketing-campaigns-and-posts/ saved to combined file.
# Article from https://insights.blackcoffer.com/google-local-service-ads-lsa-data-warehouse/ saved to combined file.
# Article from https://insights.blackcoffer.com/google-local-service-ads-missed-calls-and-messages-automation-tool/ saved to combined file.
# Article from https://insights.blackcoffer.com/marketing-ads-leads-call-status-data-tool-to-bigquery/ saved to combined file.
# Article from https://insights.blackcoffer.com/marketing-analytics-to-automate-leads-call-status-and-reporting/ saved to combined file.
# Article from https://insights.blackcoffer.com/callrail-analytics-leads-report-alert/ saved to combined file.
# Article from https://insights.blackcoffer.com/marketing-automation-tool-to-notify-lead-details-to-clients-over-email-and-phone/ saved to combined file.
# Article from https://insights.blackcoffer.com/data-etl-local-service-ads-leads-to-bigquery/ saved to combined file.
# Article from https://insights.blackcoffer.com/marbles-stimulation-using-python/ saved to combined file.
# Article from https://insights.blackcoffer.com/stocktwits-data-structurization/ saved to combined file.
# Article from https://insights.blackcoffer.com/sentimental-analysis-on-shareholder-letter-of-companies/ saved to combined file.
# Article from https://insights.blackcoffer.com/population-and-community-survey-of-america/ saved to combined file.
# Article from https://insights.blackcoffer.com/google-lsa-api-data-automation-and-dashboarding/ saved to combined file.
# Article from https://insights.blackcoffer.com/healthcare-data-analysis/ saved to combined file.
# Article from https://insights.blackcoffer.com/budget-sales-kpi-dashboard-using-power-bi/ saved to combined file.
# Article from https://insights.blackcoffer.com/amazon-buy-bot-an-automation-ai-tool-to-auto-checkouts/ saved to combined file.
# All articles combined into: C:\Users\amals\Desktop\project\combined_file\combined_articles.txt

# %% [markdown]
# This script extracts text from articles provided in a specified Excel file. It retrieves content from each URL listed in the input file, processes the text, and combines it into a single text file named combined_articles.txt. The output file is stored in a designated folder named "combined_file." Error handling is included to manage issues during the web scraping process
